# %% [markdown]
# ### Describle
#
# A Chinese word segmentation tutorial.
#
# XU HAN
#
# 2020/09/29
#
# Word segmentation tools include:
# - jieba
# - pyltp
# - thulac
# - nlpit

# %%
import pandas as pd
df = pd.read_csv("./data/data.csv")
df.head()
# Out:
#    id                                                abs  \
# 0   1  众包知识建构适应知识经济时代对创新型人才的培养需求，有效利用集体智慧推进集体知识，帮助学生成...
# 1   2  在STEM教学中，如何提高学生的动机水平，促使学生主动学习，进而提升存留率是迫切需要研究的课...
# 2   3  基于深度学习提出一种新的流体智力预测模型，并在特征可解释性上进行了初步探索。新方法的核心思想...
# 3   4  为了实现高精度的风速预测,提出一种基于深度学习的模糊粗糙集(FRS)-神经网络(CLSTM)...
# 4   5  针对当前高光谱图像处理方法无法对高光谱图像进行有效分类，为了提高光谱图像分类正确率，提出了深...
#
#                                                 news  \
# 0  摘要：[目的] 本文以众测报告为研究对象，探索众测报告作者属性、产品属性、文本、图片对预测众...
# 1  “十三五”时期是全面建成小康社会、实现第一个百年奋斗目标的决胜阶段。面对经济全球化遭遇逆流、...
# 2  人民网北京9月29日电 （记者刘佳）9月28日，文化和旅游部召开部系统安全生产工作会议，部党...
# 3  人民网北京9月29日电 据教育部网站消息，教育部发布《关于加强博士生导师岗位管理的若干意见》...
# 4  国家发改委、国家能源局近日印发《关于全面提升“获得电力”服务水平 持续优化用电营商环境的意见...
#
#                                                weibo
# 0  1月24日，台州网警工作发现有网民在微信群称：“大溪从武汉回来一千多人，被公安局全抓走，需隔...
# 1  #微博辟谣# 网传视频“一位老人带着孙子去超市赊米”引关注。经核查，该视频系站外摆拍内容，且...
# 2  #微反馈#针对网传“公交司机不允许佩戴口罩”事件，此报道不属实，纯属谣言。根据北京市做好新型...
# 3  魔女小稀 我关注到你了，我也和有关部门了解了情况。我知道你想求关注，因为现在确实存在门诊积压...
# 4  “学校开学时间：高三、初三3月2日开学；高一、高二、初一、初二3月9日开学；小学4~6年级3...

# %% [markdown]
# ### jieba
#
# - https://github.com/fxsjy/jieba

# %%
import jieba
def jieba_seg(s):
    segments = jieba.lcut(s) 
    s = " ".join(segments)
    return s

# %%
df["abs_jieba"] = df["abs"].apply(jieba_seg)
df["news_jieba"] = df["news"].apply(jieba_seg)
df["weibo_jieba"] = df["weibo"].apply(jieba_seg)

# %%
df[["abs_jieba", "news_jieba", "weibo_jieba"]]
# Out:
#                                            abs_jieba  \
# 0  众包 知识 建构 适应 知识经济 时代 对 创新型 人才 的 培养 需求 ， 有效 利用 集...
# 1  在 STEM 教学 中 ， 如何 提高 学生 的 动机 水平 ， 促使 学生 主动 学习 ，...
# 2  基于 深度 学习 提出 一种 新 的 流体 智力 预测 模型 ， 并 在 特征 可 解释性 ...
# 3  为了 实现 高精度 的 风速 预测 , 提出 一种 基于 深度 学习 的 模糊 粗糙集 ( ...
# 4  针对 当前 高 光谱 图像处理 方法 无法 对 高 光谱 图像 进行 有效 分类 ， 为了 ...
# 5  针对 当前 高 光谱 图像处理 方法 无法 对 高 光谱 图像 进行 有效 分类 , 为了 ...
# 6  表情 识别 是 在 人脸 检测 基础 之上 的 更进一步 研究 ， 是 计算机 视觉 领域 ...
# 7  哈希 算法 结合 卷积 神经网络 是 一种 常用 的 有效 图像 检索 方法 , 这种 有 ...
# 8  针对 巡 飞弹 武器 平台 ， 如何 提高 态势 感知 的 精准 性 和 实时性 以及 作战...
# 9  [ 目的 ]   本文 以众测 报告 为 研究 对象 ， 探索 众测 报告 作者 属性 、 ...
#
#                                           news_jieba  \
# 0  摘要 ： [ 目的 ]   本文 以众测 报告 为 研究 对象 ， 探索 众测 报告 作者 ...
# 1  “ 十三 五 ” 时期 是 全面 建成 小康社会 、 实现 第一个 百年 奋斗目标 的 决胜...
# 2  人民网 北京 9 月 29 日电   （ 记者 刘佳 ） 9 月 28 日 ， 文化 和 旅...
# 3  人民网 北京 9 月 29 日电   据 教育部 网站 消息 ， 教育部 发布 《 关于 加...
# 4  国家 发改委 、 国家 能源 局 近日 印发 《 关于 全面 提升 “ 获得 电力 ” 服务...
# 5  人民网 北京 9 月 29 日电   （ 朱 紫阳 ） 公安部 9 月 29 日 在 京 召...
# 6  据 美国 媒体报道 ， 过去 几周 ， 约 3500 家 美国公司 在 美国 国际贸易 法院...
# 7  新华社 日内瓦 9 月 28 日电 （ 记者 刘曲 ） 世界卫生组织 28 日 公布 的 最...
# 8  地处 南太平洋 的 岛国 基里巴斯 是 世界 上 唯一 跨越 东西南北 四个 半球 的 国家...
# 9  本报 北京 9 月 28 日电   （ 记者 吴月辉 ） 在 第 75 届 联合国大会 期间...
#
#                                          weibo_jieba
# 0  1 月 24 日 ， 台州 网警 工作 发现 有 网民 在 微信 群称 ： “ 大溪 从 武...
# 1  # 微博 辟谣 #   网传 视频 “ 一位 老人 带 着 孙子 去 超市 赊米 ” 引 关...
# 2  # 微 反馈 # 针对 网传 “ 公交 司机 不 允许 佩戴 口罩 ” 事件 ， 此 报道 ...
# 3  魔女 小稀   我 关注 到 你 了 ， 我 也 和 有关 部门 了解 了 情况 。 我 知...
# 4  “ 学校 开学 时间 ： 高三 、 初三 3 月 2 日 开学 ； 高一 、 高二 、 初一...
# 5  当前 疫情 防控 牵动 着 全国 人民 的 心 保障 “ 战疫 ”   我们 在 行动 中国...
# 6  从 1 月 25 日 中午 开始 ， 微信 、 微博 等 多个 社交 媒体 平台 上 陆续 ...
# 7  国家 卫健委 印发 的 《 新型 冠状病毒 感染 的 肺炎 诊疗 方案 （ 试行 第四版 ）...
# 8  " 简单 治 咳法 ， 蝙蝠 最 怕 高温 。 请 把 滚水 。 就是 喝 的 开水 滚开 ...
# 9  # 谣言 比 病毒 还 可怕 #   把 家里 空调 打 到 最大 的 温度 就 能 热 死...

# %% [markdown]
# ### 哈工大pyltp
# - https://pyltp.readthedocs.io/zh_CN/latest/

# %%
import os
from pyltp import Segmentor
LTP_DATA_DIR = 'E:/ltp_data'  # ltp模型目录的路径
cws_model_path = os.path.join(LTP_DATA_DIR, 'cws.model')  # 分词模型路径，模型名称为`cws.model`


def ltp_seg(s):
    segmentor = Segmentor()  # 初始化实例
    segmentor.load(cws_model_path)  # 加载模型
    words = segmentor.segment(s)# 分词
    s = " ".join(words)
    segmentor.release()  # 释放模型
    return s

# %%
df["abs_ltp"] = df["abs"].apply(ltp_seg)
df["news_ltp"] = df["news"].apply(ltp_seg)
df["weibo_ltp"] = df["weibo"].apply(ltp_seg)

# %%
df[["abs_ltp", "news_ltp", "weibo_ltp"]]
# Out:
#                                              abs_ltp  \
# 0  众 包 知识 建构 适应 知识 经济 时代 对 创新型 人才 的 培养 需求 ， 有效 利用...
# 1  在 STEM 教学 中 ， 如何 提高 学生 的 动机 水平 ， 促使 学生 主动 学习 ，...
# 2  基于 深度 学习 提出 一 种 新 的 流体 智力 预测 模型 ， 并 在 特征 可 解释性...
# 3  为了 实现 高 精度 的 风速 预测 , 提出 一 种 基于 深度 学习 的 模糊 粗糙集 ...
# 4  针对 当前 高光 谱 图像 处理 方法 无法 对 高光谱 图像 进行 有效 分类 ， 为了 ...
# 5  针对 当前 高光 谱 图像 处理 方法 无法 对 高光谱 图像 进行 有效 分类 , 为了 ...
# 6  表情 识别 是 在 人脸 检测 基础 之上 的 更 进一步 研究 ， 是 计算机 视觉 领域...
# 7  哈希 算法 结合 卷积神经 网络 是 一 种 常用 的 有效 图像 检索 方法 , 这种 有...
# 8  针对 巡飞弹 武器 平台 ， 如何 提高 态势 感知 的 精准性 和 实时性 以及 作战 任...
# 9  [ 目的 ] 本文 以 众测 报告 为 研究 对象 ， 探索 众测 报告 作者 属性 、 产...
#
#                                             news_ltp  \
# 0  摘要 ： [ 目的 ] 本文 以 众测 报告 为 研究 对象 ， 探索 众测 报告 作者 属...
# 1  “ 十三五 ” 时期 是 全面 建成 小康 社会 、 实现 第一 个 百年 奋斗 目标 的 ...
# 2  人民网 北京 9月 29日 电 （ 记者 刘佳 ） 9月 28日 ， 文化 和 旅游部 召开...
# 3  人民网 北京 9月 29日 电 据 教育部 网站 消息 ， 教育部 发布 《 关于 加强 博...
# 4  国家 发改委 、 国家 能源局 近日 印发 《 关于 全面 提升 “ 获得 电力 ” 服务 ...
# 5  人民网 北京 9月 29日 电 （ 朱紫阳 ） 公安部 9月 29日 在 京 召开 新闻 发...
# 6  据 美国 媒体 报道 ， 过去 几 周 ， 约 3500 家 美国 公司 在 美国 国际 贸...
# 7  新华社 日内瓦 9月 28日 电 （ 记者 刘曲 ） 世界 卫生 组织 28日 公布 的 最...
# 8  地处 南 太平洋 的 岛国 基里巴斯 是 世界 上 唯一 跨越 东西南北 四个半球 的 国家...
# 9  本报 北京 9月 28日 电 （ 记者 吴月辉 ） 在 第75 届 联合国 大会 期间 ， ...
#
#                                            weibo_ltp
# 0  1月 24日 ， 台州 网警 工作 发现 有 网民 在 微信 群 称 ： “ 大溪 从 武汉...
# 1  # 微博 辟谣 # 网传 视频 “ 一 位 老人 带 着 孙子 去 超市 赊米 ” 引 关注...
# 2  # 微 反馈 # 针对 网 传 “ 公交 司机 不 允许 佩戴 口罩 ” 事件 ， 此 报道...
# 3  魔女 小稀 我 关注 到 你 了 ， 我 也 和 有关 部门 了解 了 情况 。 我 知道 ...
# 4  “ 学校 开学 时间 ： 高三 、 初三 3月 2日 开学 ； 高一 、 高二 、 初一 、...
# 5  当前 疫情 防控 牵动 着 全国 人民 的 心 保障 “ 战疫 ” 我们 在 行动 中国 互...
# 6  从 1月 25日 中午 开始 ， 微信 、 微博 等 多 个 社交 媒体 平台 上 陆续 传...
# 7  国家 卫健委 印发 的 《 新型 冠状 病毒 感染 的 肺炎 诊疗 方案 （ 试行 第四 版...
# 8  " 简单 治 咳法 ， 蝙蝠 最 怕 高温 。 请 把 滚水 。 就是 喝 的 开水 滚 开...
# 9  # 谣言 比 病毒 还 可怕 # 把 家里 空调 打 到 最 大 的 温度 就 能 热 死 ...

# %% [markdown]
# ###  清华THULAC
#
# - https://github.com/thunlp/THULAC-Python

# %%
import thulac	

thu1 = thulac.thulac(seg_only=True)  #默认模式
text = thu1.cut("我爱北京天安门", text=True)  #进行一句话分词
print(text)
# Out:
# Model loaded succeed
# 我 爱 北京 天安门

# %%
def thu_seg(s):
    thu1 = thulac.thulac(seg_only=True) 
    s = thu1.cut(s, text=True)
    return s

# %%
df["abs_thu"] = df["abs"].apply(thu_seg)
df["news_thu"] = df["news"].apply(thu_seg)
df["weibo_thu"] = df["weibo"].apply(thu_seg)

# %%
df[["abs_thu", "news_thu", "weibo_thu"]]
# Out:
#                                              abs_thu  \
# 0  众包 知识 建构 适应 知识 经济 时代 对 创新型 人才 的 培养 需求 ， 有效 利用 ...
# 1  在 STEM 教学 中 ， 如何 提高 学生 的 动机 水平 ， 促使 学生 主动 学习 ，...
# 2  基于 深度 学习 提出 一 种 新 的 流体 智力 预测 模型 ， 并 在 特征 可 解释性...
# 3  为 了 实现 高 精度 的 风速 预测 , 提出 一 种 基于 深度 学习 的 模糊 粗糙集...
# 4  针对 当前 高光 谱 图像 处理 方法 无法 对 高光谱 图像 进行 有效 分类 ， 为 了...
# 5  针对 当前 高光 谱 图像 处理 方法 无法 对 高光谱 图像 进行 有效 分类 , 为 了...
# 6  表情 识别 是 在 人脸 检测 基础 之上 的 更进一步 研究 ， 是 计算机 视觉 领域 ...
# 7  哈 希算法 结合 卷积神经 网络 是 一 种 常用 的 有效 图像 检索 方法 , 这种 有...
# 8  针对 巡飞弹 武器 平台 ， 如何 提高 态势 感知 的 精准性 和 实时性 以及 作战 任...
# 9  [ 目 的 ] 本文 以 众测 报告 为 研究 对象 ， 探索 众测 报告 作者 属性 、 ...
#
#                                             news_thu  \
# 0  摘要 ： [ 目 的 ] 本文 以 众测 报告 为 研究 对象 ， 探索 众测 报告 作者 ...
# 1  “ 十三五 ” 时期 是 全面 建成 小康 社会 、 实现 第一 个 百年 奋斗 目标 的 ...
# 2  人民网 北京 9月 29日 电 （ 记者 刘佳 ） 9月 28日 ， 文化 和 旅游部 召开...
# 3  人民网 北京 9月 29日 电 据 教育部 网站 消息 ， 教育部 发布 《 关于 加强 博...
# 4  国 家 发改委 、 国 家 能源局 近日 印发 《 关于 全面 提升 “ 获得 电力 ” 服...
# 5  人民网 北京 9月 29日 电 （ 朱紫阳 ） 公安部 9月 29日 在 京 召开 新闻 发...
# 6  据 美国 媒体 报道 ， 过去 几 周 ， 约 3500 家 美国 公司 在 美国 国际 贸...
# 7  新华社 日内瓦 9月 28日 电 （ 记者 刘曲 ） 世界 卫生 组织 28日 公布 的 最...
# 8  地处 南 太平洋 的 岛国 基里巴斯 是 世界 上 唯一 跨越 东西南北 四 个 半球 的 ...
# 9  本报 北京 9月 28日 电 （ 记者 吴月辉 ） 在 第75 届 联合国 大会 期间 ， ...
#
#                                            weibo_thu
# 0  1月 24日 ， 台州 网警 工作 发现 有 网民 在 微信 群称 ： “ 大溪 从 武汉 ...
# 1  # 微博 辟谣 # 网 传视 频 “ 一 位 老人 带 着 孙子 去 超市 赊米 ” 引 关...
# 2  # 微反馈 # 针对 网传 “ 公交 司机 不 允许 佩戴 口罩 ” 事件 ， 此 报道 不...
# 3  魔女 小稀 我 关注 到 你 了 ， 我 也 和 有关 部门 了 解 了 情况 。 我 知道...
# 4  “ 学校 开学 时间 ： 高三 、 初三 3月 2日 开学 ； 高一 、 高二 、 初一 、...
# 5  当前 疫情 防控 牵动 着 全国 人民 的 心 保障 “ 战疫 ” 我们 在 行动 中国 互...
# 6  从 1月 25日 中午 开始 ， 微信 、 微博 等 多 个 社交 媒体 平台 上 陆续 传...
# 7  国 家 卫健委 印发 的 《 新型 冠状 病毒 感染 的 肺炎 诊疗 方案 （ 试行 第四 ...
# 8  " 简单 治 咳法 ， 蝙蝠 最 怕 高温 。 请 把 滚水 。 就是 喝 的 开水 滚开 ...
# 9  # 谣言 比 病毒 还 可怕 # 把 家 里 空调 打 到 最 大 的 温度 就 能 热 死...

# %% [markdown]
# ###  中科院NLPIR
#
# - https://github.com/tsroten/pynlpir
# - https://pynlpir.readthedocs.io/en/latest/tutorial.html
# - https://github.com/NLPIR-team/NLPIR

# %%
import pynlpir
pynlpir.open()

s = '欢迎科研人员、技术工程师、企事业单位与个人参与NLPIR平台的建设工作。'
pynlpir.segment(s, pos_tagging=False)
# Out:
# ['欢迎',
#  '科研',
#  '人员',
#  '、',
#  '技术',
#  '工程师',
#  '、',
#  '企事业',
#  '单位',
#  '与',
#  '个人',
#  '参与',
#  'NLPIR',
#  '平台',
#  '的',
#  '建设',
#  '工作',
#  '。']

# %%
def nlpir_seg(s):
    words = pynlpir.segment(s, pos_tagging=False)
    s = " ".join(words)
    return s

# %%
df["abs_nlpir"] = df["abs"].apply(nlpir_seg)
df["news_nlpir"] = df["news"].apply(nlpir_seg)
df["weibo_nlpir"] = df["weibo"].apply(nlpir_seg)

# %%
df[["abs_nlpir", "news_nlpir", "weibo_nlpir"]]
# Out:
#                                            abs_nlpir  \
# 0  众 包 知识 建构 适应 知识 经济 时代 对 创新 型 人才 的 培养 需求 ， 有效 利...
# 1  在 STEM 教学 中 ， 如何 提高 学生 的 动机 水平 ， 促使 学生 主动 学习 ，...
# 2  基于 深度 学习 提出 一 种 新 的 流体 智力 预测 模型 ， 并 在 特征 可 解释 ...
# 3  为了 实现 高 精度 的 风速 预测 , 提出 一 种 基于 深度 学习 的 模糊 粗糙 集...
# 4  针对 当前 高 光谱 图像 处理 方法 无法 对 高 光谱 图像 进行 有效 分类 ， 为了...
# 5  针对 当前 高 光谱 图像 处理 方法 无法 对 高 光谱 图像 进行 有效 分类 , 为了...
# 6  表情 识别 是 在 人脸 检测 基础 之上 的 更 进一步 研究 ， 是 计算机 视觉 领域...
# 7  哈 希 算法 结合 卷 积 神经 网络 是 一 种 常用 的 有效 图像 检索 方法 , 这...
# 8  针对 巡 飞弹 武器 平台 ， 如何 提高 态势 感知 的 精 准 性 和 实时 性 以及 ...
# 9  [目的]   本文 以 众 测 报告 为 研究 对象 ， 探索 众 测 报告 作者 属性 、...
#
#                                           news_nlpir  \
# 0  摘要 ： [目的]   本文 以 众 测 报告 为 研究 对象 ， 探索 众 测 报告 作者...
# 1  “ 十三五 ” 时期 是 全面 建成 小康 社会 、 实现 第一 个 百年 奋斗 目标 的 ...
# 2  人民网 北京 9月 29日 电   （ 记者 刘佳 ） 9月 28日 ， 文化 和 旅游部 ...
# 3  人民网 北京 9月 29日 电   据 教育部 网站 消息 ， 教育部 发布 《 关于 加强...
# 4  国家 发 改 委 、 国家 能源 局 近日 印发 《 关于 全面 提升 “ 获得 电力 ” ...
# 5  人民网 北京 9月 29日 电   （ 朱 紫阳 ） 公安部 9月 29日 在 京 召开 新...
# 6  据 美国 媒体 报道 ， 过去 几 周 ， 约 3500 家 美国 公司 在 美国 国际 贸...
# 7  新华社 日内瓦 9月 28日 电 （ 记者 刘 曲 ） 世界 卫生 组织 28日 公布 的 ...
# 8  地处 南 太平洋 的 岛国 基里巴斯 是 世界 上 唯一 跨越 东西南北 四 个 半 球 的...
# 9  本报 北京 9月 28日 电   （ 记者 吴月辉 ） 在 第75 届 联合国 大会 期间 ...
#
#                                          weibo_nlpir
# 0  1月 24日 ， 台州 网 警 工作 发现 有 网民 在 微信 群 称 ： “ 大 溪 从 ...
# 1  # 微 博 辟谣 #   网 传 视频 “ 一 位 老人 带 着 孙子 去 超市 赊 米 ”...
# 2  # 微 反馈 # 针对 网 传 “ 公交 司机 不 允许 佩戴 口罩 ” 事件 ， 此 报道...
# 3  魔 女 小 稀   我 关注 到 你 了 ， 我 也 和 有关 部门 了解 了 情况 。 我...
# 4  “ 学校 开学 时间 ： 高 三 、 初三 3月 2日 开学 ； 高 一 、 高 二 、 初...
# 5  当前 疫情 防 控 牵动 着 全国 人民 的 心 保障 “ 战 疫 ”   我们 在 行动 ...
# 6  从 1月 25日 中午 开始 ， 微信 、 微 博 等 多 个 社交 媒体 平台 上 陆续 ...
# 7  国家 卫 健 委 印发 的 《 新型 冠 状 病毒 感染 的 肺炎 诊疗 方案 （ 试行 第...
# 8  " 简单 治 咳 法 ， 蝙蝠 最 怕 高温 。 请 把 滚水 。 就是 喝 的 开水 滚开...
# 9  # 谣言 比 病毒 还 可怕 #   把 家里 空调 打 到 最 大 的 温度 就 能 热 ...

# %% [markdown]
# ## 3. Result evaluation

# %%
def voting(jieba, ltp, thu, nlpir):
    '''
    对每个分词工具切分的词语在另外三种分词工具切分的词语列表中出现次数≥1的情况进行计数
    '''
    jlst = jieba.split()
    llst = ltp.split()
    tlst = thu.split()
    nlst = nlpir.split()
    
    count_j = 0
    count_l = 0
    count_t = 0
    count_n = 0
    
    for item in jlst:  
        if (item in llst) or (item in tlst) or (item in nlst):
            count_j += 1
            
    for item in llst:  
        if (item in jlst) or (item in tlst) or (item in nlst):
            count_l += 1    
            
    for item in tlst:  
        if (item in jlst) or (item in llst) or (item in nlst):
            count_t += 1            
            
    for item in nlst:  
        if (item in llst) or (item in tlst) or (item in jlst):
            count_n += 1      
            
    return count_j,count_l,count_t,count_n

# %%
#函数测试
voting(df["news_jieba"][0], df["news_ltp"][0], df["news_thu"][0], df["abs_nlpir"][0])
# Out:
# (229, 241, 235, 225)

# %%
df["abs_eval"] = df.apply(lambda x: voting(x['abs_jieba'], x['abs_ltp'], x['abs_thu'],x['abs_nlpir']), axis=1)
df["news_eval"] = df.apply(lambda x: voting(x['news_jieba'], x['news_ltp'], x['news_thu'],x['news_nlpir']), axis=1)
df["weibo_eval"] = df.apply(lambda x: voting(x['weibo_jieba'], x['weibo_ltp'], x['weibo_thu'],x['weibo_nlpir']), axis=1)

# %%
# df.head()

# %%
# df.to_csv("./data/data_seg.csv", encoding="gb18030")

# %%
#对每一行实验语料的Voting计数进行求和
lst = list(df["weibo_eval"][0])
for i in range(1,df.shape[0]):
    tup = df["weibo_eval"][i]
    lst1 = list(tup)
    lst = [(lst[i]+lst1[i]) for i in range(0,len(lst))]

# %%
lst
# Out:
# [1915, 2176, 2150, 2115]
